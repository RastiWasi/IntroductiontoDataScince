# %%
import pandas as pd
import requests

# %%
response = requests.get('http://www.omdbapi.com/?i=tt3896198&apikey=99a17e8d')

# %%
call_df = pd.DataFrame([response.json()])
call_df
# Out:
#                             Title  Year  Rated     Released  Runtime  \
# 0  Guardians of the Galaxy Vol. 2  2017  PG-13  05 May 2017  136 min
#
#                        Genre    Director  \
# 0  Action, Adventure, Comedy  James Gunn
#
#                                  Writer  \
# 0  James Gunn, Dan Abnett, Andy Lanning
#
#                                     Actors  \
# 0  Chris Pratt, Zoe Saldana, Dave Bautista
#
#                                                 Plot  ... Metascore  \
# 0  The Guardians struggle to keep together as a t...  ...        67
#
#   imdbRating imdbVotes     imdbID   Type          DVD     BoxOffice  \
# 0        7.6   712,189  tt3896198  movie  22 Aug 2017  $389,813,101
#
#   Production Website Response
# 0        N/A     N/A     True
#
# [1 rows x 25 columns]

# %%
df = pd.DataFrame()
for i in range(500):
  response = requests.get('http://www.omdbapi.com/?i=tt3896198&apikey=99a17e8d')
  call_df = pd.DataFrame(response.json(), columns=['title', 'Metascore', 'imdbRating', 'imdbID', 'imdbVotes', 'BoxOffice', 'Runtime'], index=[1, 2, 3, 4, 5])
  df = pd.concat([call_df, call_df])

# %%
df
# Out:
#   title Metascore imdbRating     imdbID imdbVotes     BoxOffice  Runtime
# 1   NaN        67        7.6  tt3896198   712,189  $389,813,101  136 min
# 2   NaN        67        7.6  tt3896198   712,189  $389,813,101  136 min
# 3   NaN        67        7.6  tt3896198   712,189  $389,813,101  136 min
# 4   NaN        67        7.6  tt3896198   712,189  $389,813,101  136 min
# 5   NaN        67        7.6  tt3896198   712,189  $389,813,101  136 min
# 1   NaN        67        7.6  tt3896198   712,189  $389,813,101  136 min
# 2   NaN        67        7.6  tt3896198   712,189  $389,813,101  136 min
# 3   NaN        67        7.6  tt3896198   712,189  $389,813,101  136 min
# 4   NaN        67        7.6  tt3896198   712,189  $389,813,101  136 min
# 5   NaN        67        7.6  tt3896198   712,189  $389,813,101  136 min

# %%
df.to_csv('sample_data/rasti.csv')
